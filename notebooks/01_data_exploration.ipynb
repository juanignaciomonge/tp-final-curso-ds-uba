# %% [markdown]
# # Churn Prediction Assessment - Exploratory Data Analysis

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the csv file into a dataframe without the index column and preview it
df = pd.read_csv("/Users/juanignaciomonge/Desktop/Repositories/uba-assessment-churn-prediction/data/raw/Modelo_Clasificacion_Dataset.csv", index_col=[0])
df.head()
# Out:
#    X  numero_de_cliente  cliente_vip  internet  cliente_edad  \
# 0  1            4566150            0         1            44
# 1  2            4566430            0         0            78
# 2  3            4566445            0         1            64
# 3  4            4566621            0         1            48
# 5  6            4566907            0         1            45
#
#    cliente_antiguedad  mrentabilidad  mrentabilidad_anual  mcomisiones  \
# 0                  72        3296.69             14455.27       579.66
# 1                 159        1032.18             10141.18       790.58
# 2                 299         -52.34              4752.64       236.08
# 3                 282         485.91             10676.87      1280.47
# 5                 171        5878.27             24298.75        64.38
#
#    mactivos_margen  ...  Visa_mconsumosdolares  Visa_mlimitecompra  \
# 0           910.65  ...                  59.47             70200.0
# 1            71.21  ...                   4.22             70200.0
# 2          -422.18  ...                   0.00            196560.0
# 3         -1275.18  ...                  10.51            196560.0
# 5            22.11  ...                   0.00             49140.0
#
#    Visa_mpagado  Visa_mpagospesos  Visa_mpagosdolares  Visa_fechaalta  \
# 0           0.0         -19632.60                0.00      20130520.0
# 1           0.0          -2976.51               62.78      20060210.0
# 2           0.0         -12753.00                0.00      19960826.0
# 3           0.0          -3685.76                0.00      20150204.0
# 5           0.0          -1861.64                0.00      20050203.0
#
#    Visa_mconsumototal  Visa_cconsumos  Visa_mpagominimo  clase_binaria
# 0            14555.47            13.0            3837.6       CONTINUA
# 1              -11.55             2.0              35.1       CONTINUA
# 2             6788.67             4.0            1977.3       CONTINUA
# 3             2946.70             5.0             573.3       CONTINUA
# 5             1048.32             1.0             128.7       CONTINUA
#
# [5 rows x 105 columns]

# %%
# Drop the first column 'X' that looks like an unnecessary index
df = df.drop('X',axis=1)
df.head()
# Out:
#    numero_de_cliente  cliente_vip  internet  cliente_edad  cliente_antiguedad  \
# 0            4566150            0         1            44                  72
# 1            4566430            0         0            78                 159
# 2            4566445            0         1            64                 299
# 3            4566621            0         1            48                 282
# 5            4566907            0         1            45                 171
#
#    mrentabilidad  mrentabilidad_anual  mcomisiones  mactivos_margen  \
# 0        3296.69             14455.27       579.66           910.65
# 1        1032.18             10141.18       790.58            71.21
# 2         -52.34              4752.64       236.08          -422.18
# 3         485.91             10676.87      1280.47         -1275.18
# 5        5878.27             24298.75        64.38            22.11
#
#    mpasivos_margen  ...  Visa_mconsumosdolares  Visa_mlimitecompra  \
# 0          1411.60  ...                  59.47             70200.0
# 1           135.29  ...                   4.22             70200.0
# 2           175.66  ...                   0.00            196560.0
# 3           596.07  ...                  10.51            196560.0
# 5          4947.03  ...                   0.00             49140.0
#
#    Visa_mpagado  Visa_mpagospesos  Visa_mpagosdolares  Visa_fechaalta  \
# 0           0.0         -19632.60                0.00      20130520.0
# 1           0.0          -2976.51               62.78      20060210.0
# 2           0.0         -12753.00                0.00      19960826.0
# 3           0.0          -3685.76                0.00      20150204.0
# 5           0.0          -1861.64                0.00      20050203.0
#
#    Visa_mconsumototal  Visa_cconsumos  Visa_mpagominimo  clase_binaria
# 0            14555.47            13.0            3837.6       CONTINUA
# 1              -11.55             2.0              35.1       CONTINUA
# 2             6788.67             4.0            1977.3       CONTINUA
# 3             2946.70             5.0             573.3       CONTINUA
# 5             1048.32             1.0             128.7       CONTINUA
#
# [5 rows x 104 columns]

# %%
# Convert target variable into numeric format that is more suitable for most machine learning models
df['clase_binaria'] = df['clase_binaria'].map({'BAJA': 1, 'CONTINUA': 0})
print(df['clase_binaria'].unique())
# Out:
# [0 1]

# %%
# Preview dataframe information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 170722 entries, 0 to 189593
# Columns: 104 entries, numero_de_cliente to clase_binaria
# dtypes: float64(49), int64(55)
# memory usage: 136.8 MB

# %%
# Check column names and data types
# Temporarily display the full list of columns
pd.set_option('display.max_rows', None)  # Show all rows
print(df.dtypes)

# Reset to default after viewing
# pd.reset_option('display.max_rows')
# Out:
# numero_de_cliente                       int64
# cliente_vip                             int64
# internet                                int64
# cliente_edad                            int64
# cliente_antiguedad                      int64
# mrentabilidad                         float64
# mrentabilidad_anual                   float64
# mcomisiones                           float64
# mactivos_margen                       float64
# mpasivos_margen                       float64
# cant_total_prod                         int64
# tpaquete1                               int64
# tpaquete2                               int64
# tpaquete3                               int64
# tpaquete4                               int64
# tpaquete5                               int64
# tpaquete6                               int64
# tpaquete7                               int64
# tpaquete8                               int64
# tpaquete9                               int64
# tcuentas                                int64
# mdescubierto_preacordado              float64
# mcuentas_saldo                        float64
# ctarjeta_debito_transacciones           int64
# mautoservicio                         float64
# ctarjeta_visa                           int64
# ctarjeta_visa_transacciones             int64
# mtarjeta_visa_consumo                 float64
# ctarjeta_master                         int64
# ctarjeta_master_transacciones           int64
# mtarjeta_master_consumo               float64
# cprestamos_personales                   int64
# mprestamos_personales                 float64
# cplazo_fijo                             int64
# mplazo_fijo_dolares                   float64
# mplazo_fijo_pesos                     float64
# cfondos_comunes_inversion               int64
# mfondos_comunes_inversion_pesos       float64
# mfondos_comunes_inversion_dolares     float64
# Ctitulos                                int64
# mtitulos                              float64
# cseguro_auto                            int64
# cseguro_vivienda                        int64
# cseguro_accidentes_personales           int64
# ccaja_seguridad                         int64
# mbonos_corporativos                     int64
# mmonedas_extranjeras                    int64
# minversiones_otras                      int64
# cplan_sueldo                            int64
# mplan_sueldo                          float64
# mplan_sueldo_manual                   float64
# cplan_sueldo_transaccion                int64
# ccuenta_debitos_automaticos             int64
# mcuenta_debitos_automaticos           float64
# ctarjeta_visa_debitos_automaticos       int64
# mttarjeta_visa_debitos_automaticos    float64
# cpagodeservicios                        int64
# mpagodeservicios                      float64
# cpagomiscuentas                         int64
# mpagomiscuentas                       float64
# mcomisiones_mantenimiento             float64
# ccomisiones_otras                       int64
# mcomisiones_otras                     float64
# ccambio_monedas                         int64
# ccambio_monedas_compra                  int64
# mcambio_monedas_compra                float64
# ccambio_monedas_venta                   int64
# mcambio_monedas_venta                 float64
# ctransferencias_recibidas               int64
# mtransferencias_recibidas             float64
# ctransferencias_emitidas                int64
# mtransferencias_emitidas              float64
# cextraccion_autoservicio                int64
# mextraccion_autoservicio              float64
# ccheques_depositados                    int64
# mcheques_depositados                  float64
# ccheques_emitidos                       int64
# mcheques_emitidos                     float64
# ccheques_depositados_rechazados         int64
# mcheques_depositados_rechazados       float64
# ccheques_emitidos_rechazados            int64
# mcheques_emitidos_rechazados          float64
# thomebanking                            int64
# chomebanking_transacciones              int64
# cautoservicio                           int64
# cautoservicio_transacciones             int64
# tmovimientos_ultimos90dias              int64
# Visa_marca_atraso                     float64
# Visa_cuenta_estado                    float64
# Visa_mfinanciacion_limite             float64
# Visa_msaldototal                      float64
# Visa_msaldopesos                      float64
# Visa_msaldodolares                    float64
# Visa_mconsumospesos                   float64
# Visa_mconsumosdolares                 float64
# Visa_mlimitecompra                    float64
# Visa_mpagado                          float64
# Visa_mpagospesos                      float64
# Visa_mpagosdolares                    float64
# Visa_fechaalta                        float64
# Visa_mconsumototal                    float64
# Visa_cconsumos                        float64
# Visa_mpagominimo                      float64
# clase_binaria                           int64
# dtype: object

# %%
# Check distinct values in some columns to figure out the correct data type
unique_values = df['tcuentas'].unique()
print(unique_values)
# Out:
# [1 2]

# %%
# Change Visa_fechaalta data type to datetime.
# Ensure the column is treated as an integer (to remove decimal points), 
# but handle nulls properly by using 'errors' parameter if necessary.
df['Visa_fechaalta'] = pd.to_numeric(df['Visa_fechaalta'], errors='coerce')

# Convert to datetime, treating NaNs (null values) as valid dates
df['Visa_fechaalta'] = pd.to_datetime(df['Visa_fechaalta'], format='%Y%m%d', errors='coerce')
# Verify the changes

print(df['Visa_fechaalta'].head())
# Out:
# 0   2013-05-20
# 1   2006-02-10
# 2   1996-08-26
# 3   2015-02-04
# 5   2005-02-03
# Name: Visa_fechaalta, dtype: datetime64[ns]

# %%
# Change categorical fields into category data type instead of str since it's more efficient
# Metadata dictionary mapping columns to data types
# fields that start with a "t" (tiene/has)
# fields that start with a "c" (cantidad/quantity)
# fields that start with a "m" (monto/amount)

metadata = {
    "tcuentas": "category",
    "Visa_cuenta_estado": "category"
}

# Update the data types in the DataFrame
for column, dtype in metadata.items():
    if column in df.columns:
        try:
            df[column] = df[column].astype(dtype)
        except ValueError:
            print(f"Error converting column {column} to {dtype}")

# Check the updated DataFrame
print(df.dtypes)
# Out:
# numero_de_cliente                              int64
# cliente_vip                                    int64
# internet                                       int64
# cliente_edad                                   int64
# cliente_antiguedad                             int64
# mrentabilidad                                float64
# mrentabilidad_anual                          float64
# mcomisiones                                  float64
# mactivos_margen                              float64
# mpasivos_margen                              float64
# cant_total_prod                                int64
# tpaquete1                                      int64
# tpaquete2                                      int64
# tpaquete3                                      int64
# tpaquete4                                      int64
# tpaquete5                                      int64
# tpaquete6                                      int64
# tpaquete7                                      int64
# tpaquete8                                      int64
# tpaquete9                                      int64
# tcuentas                                    category
# mdescubierto_preacordado                     float64
# mcuentas_saldo                               float64
# ctarjeta_debito_transacciones                  int64
# mautoservicio                                float64
# ctarjeta_visa                                  int64
# ctarjeta_visa_transacciones                    int64
# mtarjeta_visa_consumo                        float64
# ctarjeta_master                                int64
# ctarjeta_master_transacciones                  int64
# mtarjeta_master_consumo                      float64
# cprestamos_personales                          int64
# mprestamos_personales                        float64
# cplazo_fijo                                    int64
# mplazo_fijo_dolares                          float64
# mplazo_fijo_pesos                            float64
# cfondos_comunes_inversion                      int64
# mfondos_comunes_inversion_pesos              float64
# mfondos_comunes_inversion_dolares            float64
# Ctitulos                                       int64
# mtitulos                                     float64
# cseguro_auto                                   int64
# cseguro_vivienda                               int64
# cseguro_accidentes_personales                  int64
# ccaja_seguridad                                int64
# mbonos_corporativos                            int64
# mmonedas_extranjeras                           int64
# minversiones_otras                             int64
# cplan_sueldo                                   int64
# mplan_sueldo                                 float64
# mplan_sueldo_manual                          float64
# cplan_sueldo_transaccion                       int64
# ccuenta_debitos_automaticos                    int64
# mcuenta_debitos_automaticos                  float64
# ctarjeta_visa_debitos_automaticos              int64
# mttarjeta_visa_debitos_automaticos           float64
# cpagodeservicios                               int64
# mpagodeservicios                             float64
# cpagomiscuentas                                int64
# mpagomiscuentas                              float64
# mcomisiones_mantenimiento                    float64
# ccomisiones_otras                              int64
# mcomisiones_otras                            float64
# ccambio_monedas                                int64
# ccambio_monedas_compra                         int64
# mcambio_monedas_compra                       float64
# ccambio_monedas_venta                          int64
# mcambio_monedas_venta                        float64
# ctransferencias_recibidas                      int64
# mtransferencias_recibidas                    float64
# ctransferencias_emitidas                       int64
# mtransferencias_emitidas                     float64
# cextraccion_autoservicio                       int64
# mextraccion_autoservicio                     float64
# ccheques_depositados                           int64
# mcheques_depositados                         float64
# ccheques_emitidos                              int64
# mcheques_emitidos                            float64
# ccheques_depositados_rechazados                int64
# mcheques_depositados_rechazados              float64
# ccheques_emitidos_rechazados                   int64
# mcheques_emitidos_rechazados                 float64
# thomebanking                                   int64
# chomebanking_transacciones                     int64
# cautoservicio                                  int64
# cautoservicio_transacciones                    int64
# tmovimientos_ultimos90dias                     int64
# Visa_marca_atraso                            float64
# Visa_cuenta_estado                          category
# Visa_mfinanciacion_limite                    float64
# Visa_msaldototal                             float64
# Visa_msaldopesos                             float64
# Visa_msaldodolares                           float64
# Visa_mconsumospesos                          float64
# Visa_mconsumosdolares                        float64
# Visa_mlimitecompra                           float64
# Visa_mpagado                                 float64
# Visa_mpagospesos                             float64
# Visa_mpagosdolares                           float64
# Visa_fechaalta                        datetime64[ns]
# Visa_mconsumototal                           float64
# Visa_cconsumos                               float64
# Visa_mpagominimo                             float64
# clase_binaria                                  int64
# dtype: object

# %%
# Check for missing values
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# numero_de_cliente                         0
# cliente_vip                               0
# internet                                  0
# cliente_edad                              0
# cliente_antiguedad                        0
# mrentabilidad                             0
# mrentabilidad_anual                       0
# mcomisiones                               0
# mactivos_margen                           0
# mpasivos_margen                           0
# cant_total_prod                           0
# tpaquete1                                 0
# tpaquete2                                 0
# tpaquete3                                 0
# tpaquete4                                 0
# tpaquete5                                 0
# tpaquete6                                 0
# tpaquete7                                 0
# tpaquete8                                 0
# tpaquete9                                 0
# tcuentas                                  0
# mdescubierto_preacordado                  0
# mcuentas_saldo                            0
# ctarjeta_debito_transacciones             0
# mautoservicio                             0
# ctarjeta_visa                             0
# ctarjeta_visa_transacciones               0
# mtarjeta_visa_consumo                     0
# ctarjeta_master                           0
# ctarjeta_master_transacciones             0
# mtarjeta_master_consumo                   0
# cprestamos_personales                     0
# mprestamos_personales                     0
# cplazo_fijo                               0
# mplazo_fijo_dolares                       0
# mplazo_fijo_pesos                         0
# cfondos_comunes_inversion                 0
# mfondos_comunes_inversion_pesos           0
# mfondos_comunes_inversion_dolares         0
# Ctitulos                                  0
# mtitulos                                  0
# cseguro_auto                              0
# cseguro_vivienda                          0
# cseguro_accidentes_personales             0
# ccaja_seguridad                           0
# mbonos_corporativos                       0
# mmonedas_extranjeras                      0
# minversiones_otras                        0
# cplan_sueldo                              0
# mplan_sueldo                              0
# mplan_sueldo_manual                       0
# cplan_sueldo_transaccion                  0
# ccuenta_debitos_automaticos               0
# mcuenta_debitos_automaticos               0
# ctarjeta_visa_debitos_automaticos         0
# mttarjeta_visa_debitos_automaticos        0
# cpagodeservicios                          0
# mpagodeservicios                          0
# cpagomiscuentas                           0
# mpagomiscuentas                           0
# mcomisiones_mantenimiento                 0
# ccomisiones_otras                         0
# mcomisiones_otras                         0
# ccambio_monedas                           0
# ccambio_monedas_compra                    0
# mcambio_monedas_compra                    0
# ccambio_monedas_venta                     0
# mcambio_monedas_venta                     0
# ctransferencias_recibidas                 0
# mtransferencias_recibidas                 0
# ctransferencias_emitidas                  0
# mtransferencias_emitidas                  0
# cextraccion_autoservicio                  0
# mextraccion_autoservicio                  0
# ccheques_depositados                      0
# mcheques_depositados                      0
# ccheques_emitidos                         0
# mcheques_emitidos                         0
# ccheques_depositados_rechazados           0
# mcheques_depositados_rechazados           0
# ccheques_emitidos_rechazados              0
# mcheques_emitidos_rechazados              0
# thomebanking                              0
# chomebanking_transacciones                0
# cautoservicio                             0
# cautoservicio_transacciones               0
# tmovimientos_ultimos90dias                0
# Visa_marca_atraso                      6101
# Visa_cuenta_estado                     6101
# Visa_mfinanciacion_limite              6101
# Visa_msaldototal                       6101
# Visa_msaldopesos                       6101
# Visa_msaldodolares                     6101
# Visa_mconsumospesos                   21503
# Visa_mconsumosdolares                 21503
# Visa_mlimitecompra                     6101
# Visa_mpagado                           6101
# Visa_mpagospesos                      21503
# Visa_mpagosdolares                    21503
# Visa_fechaalta                         6101
# Visa_mconsumototal                    21503
# Visa_cconsumos                        21503
# Visa_mpagominimo                       6101
# clase_binaria                             0
# dtype: int64

# %%
# Check for duplicate rows
duplicates = df.duplicated().sum()
print(f"\nNumber of duplicate rows: {duplicates}")
# Out:
# Number of duplicate rows: 0

# %%
# Checking the distribution of the target variable
target_column = 'clase_binaria'
if target_column in df.columns:
    print(f"\nDistribution of target variable ({target_column}):")
    print(df[target_column].value_counts())
    sns.countplot(data=df, x=target_column)
    plt.title("Distribution of Target Variable")
    plt.show()
else:
    print(f"\nTarget column '{target_column}' not found in the dataset. Please check the column name.")
# Out:
# Distribution of target variable (clase_binaria):
# clase_binaria
# CONTINUA    168887
# BAJA          1835
# Name: count, dtype: int64

# %%
# Correlation matrix heatmap
# Select only numeric columns
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Calculate the correlation matrix for the numeric columns
corr = numeric_df.corr()

# Plot the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm')
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
# As the heatmap looks very cluttered I will select a subset of key features (need to search for potentially correlated variables)
# Example: Subset of numerical columns for better visualization
important_columns = ['mdescubierto_preacordado', 'mautoservicio', 'ctarjeta_visa', 'cfondos_comunes_inversion']  # Specify relevant columns
numeric_df_subset = numeric_df[important_columns]

# Calculate and plot correlation matrix for the subset
corr = numeric_df_subset.corr()
plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm')
plt.title("Correlation Matrix Heatmap (Subset)")
plt.show()

# %%
# Categorical feature analysis
categorical_cols = df.select_dtypes(include=['category']).columns
for col in categorical_cols:
    if col != target_column:  # Avoid plotting the target column here
        print(f"\nDistribution of {col}:")
        sns.countplot(data=df, y=col, order=df[col].value_counts().index)
        plt.title(f"Distribution of {col}")
        plt.show()
# Out:
# Distribution of tcuentas:
# Distribution of Visa_cuenta_estado:

# %%
# Feature Importance
from sklearn.ensemble import RandomForestClassifier
numeric_cols = df.select_dtypes(include=np.number).columns
target_column = 'clase_binaria'
model = RandomForestClassifier(n_estimators=100, random_state=42)

# Use the variable target_column to access the column in the DataFrame
model.fit(df[numeric_cols], df[target_column])

# %%
# Get feature importances
feature_importances = model.feature_importances_
feature_importance_df = pd.DataFrame({
    'feature': numeric_cols,
    'importance': feature_importances
})
# Sort by importance
feature_importance_df = feature_importance_df.sort_values(by='importance', ascending=False)
# Limit the number of features to display
top_n = 30
feature_importance_df = feature_importance_df.head(top_n)
# Plot the top features
plt.figure(figsize=(10, 6))
sns.barplot(x='importance', y='feature', data=feature_importance_df)
plt.title('Top Feature Importance')
plt.show()
